# %%
input_number= input("Enter Number: ")
input_base= int(input("Enter Input Number Base: "))
output_base= int(input("Enter Output Number Base: "))

if("." not in input_number):
    input_number = input_number + ".0"
    
def check_validity(input_number ,input_base):
    lst= input_number.split(".")
    c1=0
    
    for i in lst[0]:
        
        if(48 <=ord(i) <=57):
            a1=int(i)
            
            if(a1>input_base):
                c1=c1+1
        else:
            a1=i.upper()
            a2=ord(i)-55
            
            if(a2 >input_base):
                c1=c1+1
    for i in lst[1]:
        
        if(48<=ord(i)<=57):
            a1=int(i)
            if(a1 >input_base):
                c1=c1+1
        else:
            a1=i.upper()
            a2=ord(i)-55
            
            if(a2 >input_base):
                c1=c1+1
                
    if(c1==0):
        conversion(input_number,input_base,output_base)
    else:
        print("Please Enter a Valid Number in the Input Base!")
        
def conversion(input_number,input_base,output_base):
    lst=input_number.split(".")
    c1=0
    a2=len(lst[0])-1
    
    for i in lst[0]: #Integer Part of the Number
        
        if(48<=ord(i)<=57):
            a1=int(i)
            c1=c1+a1*(input_base**a2)
            
        else:
            l=i.upper()
            a1=ord(i)-55
            c1=c1+a1*(input_base**a2)
            
        a2=a2-1
        
    b1=0
    b2=-1
    for i in lst[1] : #Fractional Part of the Number
        
        if(48<=ord(i)<=57):
            a1=int(i)
            b1=b1+a1*(input_base**b2)
            
        else:
            l=i.upper()
            a=ord(i)-55
            b1=b1+a1*(input_base**b2)
            
        b2=b2+1
        
    dec=c1+b1   #Any Base to Decimal till this part.
    sec=str(dec).split(".")
    a1=sec[0]  #Integer Part of the Number to Decimal
    lst1=[]
    r =""
    c2=int(a1)
    
    while(c2>=1):
        a2=c2%output_base
        c2=c2//output_base
        
        if(0<=a2<=9):
            r=str(a2)+r
            
        else:
            d=a2+55
            b2=chr(d)
            r=str(b2)+r
            
    lst1.append(r)
    b1=""
    m=len(sec[1]) #Fractional Part of the Number to Decimal
    n=int(sec[1])/(10**m)
    
    for i in range(5):
        n=n*output_base
        c1=int(n)
        
        if(0<=c1<=9):
            b1=b1+str(c1)
            
        else:
            u=c1+55
            y=chr(u)
            b1=b1+str(y)
        n=n-int(n)
        
    lst1.append(b1)
    c1=".".join(lst1)
    
    print(c1)
check_validity(input_number,input_base)
# Out:
# Enter Number: 11000
# Enter Input Number Base: 2
# Enter Output Number Base: 10
# 24.00000

# %%
n1=input("Enter the First Number: ")
n2=input("Enter the Second Number: ")
if("." not in n1):
    n1=n1+".0"
if("." not in n2):
    n2=n2+".0"
input_base=int(input("Enter the Input Base: "))

def check_validity(input_number ,input_base):
    lst= input_number.split(".")
    c1=0
    
    for i in lst[0]:
        
        if(48 <=ord(i) <=57):
            a1=int(i)
            
            if(a1>input_base):
                c1=c1+1
        else:
            a1=i.upper()
            a2=ord(i)-55
            
            if(a2 >input_base):
                c1=c1+1
    for i in lst[1]:
        
        if(48<=ord(i)<=57):
            a1=int(i)
            if(a1 >input_base):
                c1=c1+1
        else:
            a1=i.upper()
            a2=ord(i)-55
            
            if(a2 >input_base):
                c1=c1+1
                
    if(c1==0):
        return True
    
    else:
        return False
    
def conversion(input_number,input_base):
    lst=input_number.split(".")
    c1=0
    a2=len(lst[0])-1
    
    for i in lst[0]: #Integer Part of the Number
        
        if(48<=ord(i)<=57):
            a1=int(i)
            c1=c1+a1*(input_base**a2)
            
        else:
            l=i.upper()
            a1=ord(i)-55
            c1=c1+a1*(input_base**a2)
            
        a2=a2-1
        
    b1=0
    b2=-1
    for i in lst[1] : #Fractional Part of the Number
        
        if(48<=ord(i)<=57):
            a1=int(i)
            b1=b1+a1*(input_base**b2)
            
        else:
            l=i.upper()
            a=ord(i)-55
            b1=b1+a1*(input_base**b2)
            
        b2=b2+1
        
    dec=c1+b1   #Any Base to Decimal till this part.
    
    return dec

def operation(dec,input_base):
    sec=str(dec).split(".")
    a1=sec[0]  #Integer Part of the Number to Decimal
    lst1=[]
    r =""
    c2=int(a1)
    
    while(c2>=1):
        a2=c2%input_base
        c2=c2//input_base
        
        if(0<=a2<=9):
            r=str(a2)+r
            
        else:
            d=a2+55
            b2=chr(d)
            r=str(b2)+r
            
    lst1.append(r)
    b1=""
    m=len(sec[1]) #Fractional Part of the Number to Decimal
    n=int(sec[1])/(10**m)
    
    for i in range(5):
        n=n*input_base
        c1=int(n)
        
        if(0<=c1<=9):
            b1=b1+str(c1)
            
        else:
            u=c1+55
            y=chr(u)
            b1=b1+str(y)
        n=n-int(n)
        
    lst1.append(b1)
    c1=".".join(lst1)
    
    print(c1)
    
if((check_validity(n1,input_base)) and (check_validity(n2,input_base))):
   
    num_1=conversion(n1,input_base)
    num_2=conversion(n2,input_base)
    o=input("Enter the operation which you want to perform across the numbers +,-,/,* : ")
   
    if(o=="+"):
        dec=num_1+num_2
   
    elif(o=="-"):
        dec=num_1-num_2
   
    elif(o=="*"):
        dec=num_1*num_2
   
    elif(o=="/"):
        dec=num_1/num_2
    else:
        print("Enter a valid operator!")
    operation(dec,input_base)
    
elif((check_validity(num_1,input_base) and check(num_2,input_base))==False):
    print("Please Enter a Valid Number in the Input Base of "+num_1+" and "+num_2)
    
else:
    if(check_validity(num_1,input_base)):
        print("Please Enter a Valid Number in the Input Base of "+num_1)
    else:
        print("Please Enter a Valid Number in the Input Base of "+num_2)
# Out:
# Enter the First Number: 1100
# Enter the Second Number: 1100
# Enter the Input Base: 2
# Enter the operation which you want to perform across the numbers:+,-,/,* = +
# 11000.00000
